# %%
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

seed = 0
rng = np.random.default_rng(seed)

# Definition of marketing campaign
B = 10
n_marketing_campaigns = 7
expected_costs = rng.uniform(size=n_marketing_campaigns)
expected_rewards = rng.uniform(size=n_marketing_campaigns)

reward_cost_ratio = expected_rewards / expected_costs
best_arm = np.argmax(reward_cost_ratio)
print(reward_cost_ratio)
print(f"best arm is {best_arm}")

def get_regret(rewards, costs, chosen_arm, best_arm):
    cost_this = costs[chosen_arm]
    rew_this = rewards[chosen_arm]
    rew_best = rewards[best_arm]
    cost_best = costs[best_arm]
    return cost_this * (rew_best / cost_best - rew_this / cost_this)
# Out:
# [1.14527542e+00 2.01501766e+00 2.28213816e+01 4.93629928e+01
#  3.36726962e-03 9.39358025e-01 5.53636575e-02]
# best arm is 3

# %%
from components.bandits.wucb import WUCB
from components.bandits.ucb_variants import UCB
from components.bandits.bts import BudgetedThompsonSampling

w_ucb = WUCB(name="w-UCB", k=n_marketing_campaigns, seed=seed, r=1.0, adaptive=True)
m_ucb = UCB(name="m-UCB", type="m", k=n_marketing_campaigns, seed=seed, alpha=1.0)
bts = BudgetedThompsonSampling(name="BTS", k=n_marketing_campaigns, seed=seed)

approach_list = [w_ucb, m_ucb, bts]
approaches = {a.name: a for a in approach_list}
budget = {a.name: B for a in approach_list}

results = []

while True:
    rewards_in_this_round = (rng.uniform(size=n_marketing_campaigns) < expected_rewards).astype(float)
    costs_in_this_round = (rng.uniform(size=n_marketing_campaigns) < expected_costs).astype(float)

    for name, approach in approaches.items():
        if name not in budget:
            continue
        chosen_arm = approach.sample()
        r, c = rewards_in_this_round[chosen_arm], costs_in_this_round[chosen_arm]
        approach.update(chosen_arm, float(r), float(c))
        this_regret = get_regret(expected_rewards, expected_costs, chosen_arm, best_arm)
        budget[name] -= costs_in_this_round[chosen_arm]
        results.append([
            name, chosen_arm, r, c, this_regret, B - budget[name]
        ])
        if budget[name] <= 0:
            del budget[name]

    if len(budget) == 0:
        break

# %%
import pandas as pd

df = pd.DataFrame(results, columns=["approach", "arm", "r", "c", "regret", "spent budget"])
df["regret (cumulative)"] = df.groupby("approach")["regret"].cumsum()
df["reward (cumulative)"] = df.groupby("approach")["r"].cumsum()

# %%
sns.relplot(data=df, x="spent budget", y="regret (cumulative)", hue="approach", kind="line", errorbar=None)
plt.show()
# Out:
# C:\Users\heyden\Miniconda3\envs\OmegaUCB\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# - after B, the best policy could have earnt mu_r^* / mu_c^* * B. A suboptimal policy would have earned mu_r / mu_c * B
# - the difference between both is mu_r^* / mu_c^* * B - mu_r / mu_c * B = (mu_r^* / mu_c^* - mu_r / mu_c) * B = Delta * B
# - the budget that a policy spends in a round is on average

# %%
seed = 1
rng = np.random.default_rng(seed)

# Definition of marketing campaign
B = 10
n_marketing_campaigns = 5
maximum_costs = rng.uniform(size=n_marketing_campaigns)
maximum_rewards = rng.uniform(size=n_marketing_campaigns)

reward_cost_ratio = (maximum_rewards / 2) / (maximum_costs / 2)
best_arm = np.argmax(reward_cost_ratio)
print(reward_cost_ratio)
print(f"best arm is {best_arm}")
# Out:
# [0.82709762 0.87084083 2.8385144  0.57934329 0.08837823]
# best arm is 2

# %%
from components.bandits.w_star_ucb import WStarUCB

w_ucb = WUCB(name="w-UCB", k=n_marketing_campaigns, seed=seed, r=1.0 / 4, adaptive=True)
w_star = WStarUCB(name="w-Star", k=n_marketing_campaigns, seed=seed, r=1.0 / 4, adaptive=True)
m_ucb = UCB(name="m-UCB", type="m", k=n_marketing_campaigns, seed=seed, alpha=1.0)
bts = BudgetedThompsonSampling(name="BTS", k=n_marketing_campaigns, seed=seed)

approach_list = [w_ucb, m_ucb, bts, w_star]
approaches = {a.name: a for a in approach_list}
budget = {a.name: B for a in approach_list}

results = []

while True:
    rewards_in_this_round = rng.uniform(high=maximum_rewards)
    costs_in_this_round = rng.uniform(high=maximum_costs)

    for name, approach in approaches.items():
        if name not in budget:
            continue
        chosen_arm = approach.sample()
        r, c = rewards_in_this_round[chosen_arm], costs_in_this_round[chosen_arm]
        approach.update(chosen_arm, float(r), float(c))
        this_regret = get_regret(expected_rewards, expected_costs, chosen_arm, best_arm)
        budget[name] -= costs_in_this_round[chosen_arm]
        results.append([
            name, chosen_arm, r, c, this_regret, B - budget[name]
        ])
        if budget[name] <= 0:
            del budget[name]

    if len(budget) == 0:
        break

# %%
import pandas as pd

df = pd.DataFrame(results, columns=["approach", "arm", "r", "c", "regret", "spent budget"])
df["regret (cumulative)"] = df.groupby("approach")["regret"].cumsum()
df["reward (cumulative)"] = df.groupby("approach")["r"].cumsum()

import matplotlib.pyplot as plt
import seaborn as sns

sns.relplot(data=df, x="spent budget", y="regret (cumulative)", hue="approach", kind="line", errorbar=None)
plt.show()
# Out:
# C:\Users\heyden\Miniconda3\envs\OmegaUCB\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# import matplotlib.animation as animation
# import os

# fig, axes = plt.subplots(nrows=2)
# for ax in axes:
#     ax.set_xlim([0, 100])

# alpha = 0.01
# x = (rng.uniform(size=100) < 0.2).astype(float)
# means = []
# cis = []
# data = pd.DataFrame(columns=['samples', 'mean', '1 / mean', 'ci', 'lcb', 'ucb'])

# ax_left = axes[0]
# ax_right = axes[1]
# ax_right.set_ylim(0, 40)

# def conf_width(x, a):
#     return np.sqrt(1 / (2 * len(x)) * np.log(2 / a))

# def update(i):
#     m = np.mean(x[:i + 1])
#     ci = conf_width(x[:i + 1], alpha)
#     if i == 0:
#         return
#     data.loc[i] = [i + 1, m, 1 / m, ci, m - ci / 2, m + ci / 2]

#     # ci for x
#     ax_left.fill_between(data.loc[i - 1:i + 1, "samples"], data.loc[i - 1:i + 1, "lcb"], data.loc[i - 1:i + 1, "ucb"], 
#                          color="black" if data.loc[i, "lcb"] > 0 else "red", 
#                          alpha=0.3, lw=0)
#     sns.lineplot(data.loc[i - 1: i + 1], x="samples", y="mean", ax=ax_left, color="black")

#     # ci for 1 / x
#     ax_right.fill_between(data.loc[i - 1:i + 1, "samples"], 1 / data.loc[i - 1:i + 1, "ucb"], 1 / data.loc[i - 1:i + 1, "lcb"],  
#                          color="black" if data.loc[i, "lcb"] > 0 else "red", 
#                          alpha=0.3, lw=0)
#     sns.lineplot(data.loc[i - 1: i + 1], x="samples", y="1 / mean", ax=ax_right, color="black")
#     # ax_right.set_ylim(bottom=0)

# ani = animation.FuncAnimation(fig, update, repeat=True,
#                                     frames=len(x) - 1, interval=50)

# # To save the animation using Pillow as a gif
# writer = animation.PillowWriter(fps=15,
#                                 metadata=dict(artist='Marco Heyden'),
#                                 bitrate=1800)
# ani.save(os.path.join(os.getcwd(), "figures", "ci.gif"), writer=writer)

# plt.show()

# %% [markdown]
# ## UCB1 illustration

# %% [markdown]
# First we import the basic libraries and define our setting:
# - we specify the expected payoff of each call template and the expected duration of the script.
# - In reality, both these quantities are unknown.
# - We assume that the company restricts each call to a length of at maximum 10 minutes. We use this to normalize the call durations.

# %%
import numpy as np
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="ticks")
plt.style.use("dark_background")

import matplotlib as mpl
# mpl.rcParams['text.usetex'] = True
# mpl.rcParams['text.latex.preamble'] = r'\usepackage{inconsolata}\renewcommand{\familydefault}{\sfdefault}\everymath={\sf}'
mpl.rcParams['legend.frameon'] = True
mpl.rcParams["figure.figsize"] = (10, 5)
# mpl.rc('font', family='sans-serif')
mpl.rcParams['font.sans-serif'] = ['DejaVu Sans Mono']

fontsize = 20
mpl.rcParams.update({'font.size': fontsize})
params = {'axes.labelsize': fontsize,'axes.titlesize':fontsize, 'legend.fontsize': fontsize, 
          'xtick.labelsize': fontsize, 'ytick.labelsize': fontsize}
mpl.rcParams.update(params)

expected_payoffs = np.array([0.1, 0.3, 0.7])
expected_duration_minutes = np.array([1, 2, 8])
maximum_duration = 10.0

expected_costs = expected_duration_minutes / maximum_duration
min_cost =  1e-2
# max_minutes = int(2 * 4 * 5 * 8 * 60)
max_minutes = 10000
n_samples = int(max_minutes * 1.2)
rng = np.random.default_rng(0)

label_random = "random script"

class Result:
    def  __init__(self, x, y, label, color):
        self.x = x
        self.y = y
        self.label = label
        self.color = color

all_results = []

plt.bar([f"arm {i + 1}" for i in range(len(expected_payoffs))], expected_payoffs / expected_duration_minutes)
plt.ylabel("payoffs / call duration")
plt.savefig(os.path.join(os.getcwd(), "figures", "arms_medium.png"))

# %%
def compute_ci(n, t):
    if n == 0 or t == 0:
        return np.infty
    return np.sqrt(2 * np.log(t) / n)

alpha = 0.01
payoffs = rng.uniform(size=(len(expected_payoffs), n_samples)) < np.expand_dims(expected_payoffs, -1)
means = []
cis = []
columns=["arm", 'time', "plays", 'mean', 'ci', 'lcb', 'ucb', 'reward']

def get_best_arm(data: pd.DataFrame):
    best_arm_index = np.argmax(data["ucb"]) 
    row = data.iloc[best_arm_index]
    return row["arm"]

reward = 0
timestep_df = []
data = []
for i in range(n_samples):
    if i < len(expected_payoffs):
        played_arm = i
    else:
        played_arm = get_best_arm(timestep_df)
    rows_for_timestep = []
    for arm in range(len(expected_payoffs)):
        if i > 0:
            last_row_for_arm = timestep_df.iloc[arm]
            last_mean = last_row_for_arm["mean"]
            last_number_plays = last_row_for_arm["plays"]
        else:
            last_mean = 0
            last_number_plays = 0
        if arm == played_arm:
            sample = payoffs[arm, i]
            reward += sample
            new_plays = last_number_plays + 1
            new_mean = ((last_mean * last_number_plays) + sample) / new_plays
        else:
            new_mean = last_mean
            new_plays = last_number_plays
        new_ci = compute_ci(new_plays, i)
        rows_for_timestep.append([arm, i, new_plays, new_mean, new_ci, new_mean - new_ci, new_mean + new_ci, reward])
        data.append([arm, i, new_plays, new_mean, new_ci, new_mean - new_ci, new_mean + new_ci, reward])
    timestep_df = pd.DataFrame(rows_for_timestep, columns=columns)

data = pd.DataFrame(data, columns=columns)
data["played"] = data.groupby("arm")["plays"].diff().astype("bool")

payoffs_strategy_best = np.cumsum(payoffs[np.argmax(expected_payoffs)])
payoffs_strategy_worst = np.cumsum(payoffs[np.argmin(expected_payoffs)])
randomly_played_arms = rng.integers(0, len(expected_payoffs), len(payoffs_strategy_best))
payoffs_strategy_random = np.cumsum([r[i] for r, i in zip(payoffs.T, randomly_played_arms)])

result_s3_time = Result(range(len(payoffs_strategy_best)), payoffs_strategy_best, "script 3", "lime")
result_s1_time = Result(range(len(payoffs_strategy_worst)), payoffs_strategy_worst, "script 1", "magenta")
result_random_time = Result(range(len(payoffs_strategy_random)), payoffs_strategy_random, label_random, "cyan")

# %%
all_results = [result_s1_time, result_s3_time, result_random_time]

plt.fill_between(result_s3_time.x, result_s3_time.y, result_s1_time.y, color="white", alpha=0.3)
for result in all_results:
    ax = sns.lineplot(x=result.x, y=result.y, color=result.color, label=result.label, errorbar=None)

sns.move_legend(ax, "upper left")
sns.despine()
plt.xlabel("Total number of plays")
plt.ylabel("Sum of payoffs")
plt.tight_layout(pad=.5)
plt.savefig(os.path.join(os.getcwd(), "figures", "medium_1.png"))

# %%
payoffs_ucb1 = np.array(data.loc[data["arm"] == 0]["reward"])
result_ucb_time = Result(range(len(payoffs_ucb1)), payoffs_ucb1, "UCB", "white")

all_results = [result_s1_time, result_s3_time, result_random_time, result_ucb_time]

plt.fill_between(result_s3_time.x, result_s3_time.y, result_s1_time.y, color="white", alpha=0.3)
for result in all_results:
    ax = sns.lineplot(x=result.x, y=result.y, color=result.color, label=result.label)

sns.move_legend(ax, "upper left")
sns.despine()
plt.legend()
plt.xlabel("Total number of plays")
plt.ylabel("Sum of payoffs")
plt.tight_layout(pad=.5)
plt.savefig(os.path.join(os.getcwd(), "figures", "medium_2.png"))

# %% [markdown]
# ## Why the budget matters
#
# Now, let's have a look what happens if we do not take into account the costs of the calls. For this, we change the x-axis from "time" to "total call duration".
#
# Let's first have a look at the "bang for buck" ratio, i.e., payoff per minute:

# %%
payoff_per_minute = expected_payoffs / (expected_costs * maximum_duration)

# sample the costs from a beta distribution
p = 2
def q_for_p(p, expected_val):
    e_inv = 1 / expected_val
    return p / expected_val - p

def bernoulli(p):
    return int(rng.uniform() < p)

def sample(func, *args):
    return func(*args)

params = [(p, q_for_p(p, e)) for e in expected_costs]
# params = [[e] for e in expected_costs]
costs = np.array([[sample(rng.beta, *args) for args in params] 
                  for _ in range(n_samples)]).T

payoff_per_minute
# Out:
# array([0.1   , 0.15  , 0.0875])

# %%
idx_best = np.argmax(payoff_per_minute)
idx_worst = np.argmin(payoff_per_minute)

payoffs_strategy_best = np.cumsum(payoffs[idx_best])
payoffs_strategy_worst = np.cumsum(payoffs[idx_worst])

minutes_best = costs[idx_best, :].cumsum() * maximum_duration # np.arange(len(payoffs_strategy_best)) * expected_duration_minutes[idx_best]
minutes_worst = costs[idx_worst, :].cumsum() * maximum_duration  # np.arange(len(payoffs_strategy_worst)) * expected_duration_minutes[idx_worst]
minutes_random = np.array([expected_duration_minutes[randomly_played_arms[i]] for i in range(n_samples)]).cumsum()

result_best_minutes = Result(minutes_best, payoffs_strategy_best, f"script {idx_best + 1}", "magenta")
result_worst_minutes = Result(minutes_worst, payoffs_strategy_worst, f"script {idx_worst + 1}", "lime")
result_random_minutes = Result(minutes_random, result_random_time.y, result_random_time.label, result_random_time.color)

payoffs_strategy_worst_stratified = []
for m_best in minutes_best:
    pay_worst = [p for p, m_worst in zip(payoffs_strategy_worst, minutes_worst) if m_worst <= m_best]
    payoffs_strategy_worst_stratified.append(pay_worst[-1] if len(pay_worst) else 0.0) 

result_worst_stratified = Result(minutes_best, payoffs_strategy_worst_stratified, "", "")

played_arms_ucb = np.array(data[data["played"]]["arm"])
minutes_ucb = np.array([costs[int(played_arms_ucb[i]), i] for i in range(n_samples)]).cumsum() * maximum_duration
result_ucb_minutes = Result(minutes_ucb, result_ucb_time.y, result_ucb_time.label, result_ucb_time.color)

all_results = [result_worst_minutes, result_best_minutes, result_random_minutes, result_ucb_minutes]
plt.fill_between(minutes_best, result_best_minutes.y, result_worst_stratified.y, color="white", alpha=0.3)
for result in all_results:
    ax = sns.lineplot(x=result.x, y=result.y, color=result.color, label=result.label, errorbar=None)

sns.move_legend(ax, "upper left")
sns.despine()

# max_minutes = np.max(minutes_best)
max_payoff = payoffs_strategy_best[len([m for m in minutes_best if m < max_minutes]) - 1]
plt.xlim(0, max_minutes)
plt.ylim(0, max_payoff * 1.1)
plt.xlabel("Total duration of calls")
plt.ylabel("Sum of payoffs")
plt.tight_layout(pad=.5)

plt.savefig(os.path.join(os.getcwd(), "figures", "medium_3.png"))

# %% [markdown]
# We see that the arm with the lowest payoffs (arm 1) has the highest payoff per minute. This suggests that, if total call time is limited or costly, one should rather accept low payoffs to save time during calls. The following graph shows that UCB1 no longer performs well.

# %% [markdown]
# First sample the payoffs

# %%
# payoffs = rng.uniform(size=(len(expected_payoffs), n_samples)) < np.expand_dims(expected_payoffs, -1)

# %% [markdown]
# Then run the composite approach

# %%
def get_best_arm(data: pd.DataFrame):
    best_arm_index = np.argmax(data["ucb"]) 
    row = data.iloc[best_arm_index]
    return row["arm"]

def compute_ci(n, t):
    if n == 0 or t == 0:
        return np.infty
    return np.sqrt(2 * np.log(t) / n)

columns=["arm", 'time', "plays", 'mean', 'ci', 'lcb', 'ucb', 'reward']
reward = 0
timestep_df = []
data_ucb_scaled = []
for i in range(n_samples):
    if i < len(expected_payoffs):
        played_arm = i
    else:
        played_arm = get_best_arm(timestep_df)
    rows_for_timestep = []
    for arm in range(len(expected_payoffs)):
        cost_expectation = expected_costs[arm]
        if i > 0:
            last_row_for_arm = (timestep_df.iloc[arm])
            last_mean = last_row_for_arm["mean"]
            last_number_plays = last_row_for_arm["plays"]
        else:
            last_mean = 0
            last_number_plays = 0
        if arm == played_arm:
            sample = payoffs[arm, i]
            reward += sample
            new_plays = last_number_plays + 1
            new_mean = ((last_mean * last_number_plays) + sample) / new_plays
        else:
            new_mean = last_mean
            new_plays = last_number_plays
        new_ci = compute_ci(new_plays, i)
        rows_for_timestep.append([arm, i, new_plays, new_mean, new_ci, 
                                                       new_mean - new_ci, 
                                                       (new_mean + new_ci) / cost_expectation, reward])
        data_ucb_scaled.append([arm, i, new_plays, new_mean, new_ci, 
                                                       new_mean - new_ci, 
                                                       (new_mean + new_ci) / cost_expectation, reward])
    timestep_df = pd.DataFrame(rows_for_timestep, columns=columns)

data_ucb_scaled = pd.DataFrame(data_ucb_scaled, columns=columns)
data_ucb_scaled["played"] = data_ucb_scaled.groupby("arm")["plays"].diff().astype("bool")

payoffs_ucb_scaled = np.array(data_ucb_scaled.loc[data_ucb_scaled["arm"] == 0]["reward"])
played_arms_ucb_scaled = np.array(data_ucb_scaled[data_ucb_scaled["played"]]["arm"])
minutes_ucb_scaled = np.array([costs[int(played_arms_ucb_scaled[i]), i] for i in range(n_samples)]).cumsum() * maximum_duration

result_ucb_scaled = Result(minutes_ucb_scaled, payoffs_ucb_scaled, "scaled UCB", "white")

# %%
all_results = [result_worst_minutes, result_best_minutes, result_random_minutes, result_ucb_scaled]
plt.fill_between(minutes_best, result_best_minutes.y, result_worst_stratified.y, color="white", alpha=0.3)
for result in all_results:
    ax = sns.lineplot(x=result.x, y=result.y, color=result.color, label=result.label)

sns.move_legend(ax, "upper left")
sns.despine()

# max_minutes = np.max(minutes_best)
max_payoff = payoffs_strategy_best[len([m for m in minutes_best if m < max_minutes]) - 1]
plt.xlim(0, max_minutes)
plt.ylim(0, max_payoff * 1.1)
plt.xlabel("Total duration of calls")
plt.ylabel("Sum of payoffs")
plt.tight_layout(pad=.5)

plt.savefig(os.path.join(os.getcwd(), "figures", "medium_3_1.png"))

# %% [markdown]
# ## GIF

# %% [markdown]
# The code below creates a gif illustrating the behavior of UCB1 over time.

# %%
# import matplotlib.animation as animation
# import warnings
# warnings.filterwarnings("ignore")

# colors = sns.cubehelix_palette(n_colors=len(expected_payoffs))
# palette = {float(i): colors[i] for i in range(len(expected_payoffs))}

# def update(i):
#     if i == 0:
#         return
#     d = data.loc[np.logical_and(data["time"] > i - 1, data["time"] <= i + 1)]
#     if i == 5:
#         print(d)
#     sns.lineplot(d, x="time", y="mean", hue="arm", legend=None, palette=palette, errorbar=None, ax=axes[0])
#     sns.lineplot(d, x="time", y="ucb", hue="arm", legend=None, palette=palette, errorbar=None, ax=axes[0], ls="dotted")
#     sns.lineplot(d, x="time", y="plays", hue="arm", legend=None, palette=palette, errorbar=None, ax=axes[1])
#     # for arm in range(len(expected_payoffs)):
#     #     arm_data = d.loc[d["arm"] == arm]
#     #     for ax in axes:
#     #         ax.axvspan()
#     #     plt.fill_between(arm_data["time"], arm_data["mean"], arm_data["ucb"],   
#     #                      alpha=0.3, lw=0, color=palette[arm])

# fig, axes = plt.subplots(nrows=2, sharex=True)
# for ax in axes:
#     ax.set_xlim([0, n_samples])
# ani = animation.FuncAnimation(fig, update, repeat=True,
#                               frames=len(data), interval=50)

# # To save the animation using Pillow as a gif
# writer = animation.PillowWriter(fps=5,
#                                 metadata=dict(artist='Marco Heyden'),
#                                 bitrate=1800)
# ani.save(os.path.join(os.getcwd(), "figures", "ucb1.gif"), writer=writer)

# plt.show()

# %% [markdown]
# ### m-UCB

# %%
idx_best = np.argmax(payoff_per_minute)
idx_worst = np.argmin(payoff_per_minute)

payoffs_strategy_best = np.cumsum(payoffs[idx_best])
payoffs_strategy_worst = np.cumsum(payoffs[idx_worst])

minutes_best = costs[idx_best, :].cumsum() * maximum_duration # np.arange(len(payoffs_strategy_best)) * expected_duration_minutes[idx_best]
minutes_worst = costs[idx_worst, :].cumsum() * maximum_duration  # np.arange(len(payoffs_strategy_worst)) * expected_duration_minutes[idx_worst]
minutes_random = np.array([expected_duration_minutes[randomly_played_arms[i]] for i in range(n_samples)]).cumsum()

payoffs_strategy_worst_stratified = []
for m_best in minutes_best:
    pay_worst = [p for p, m_worst in zip(payoffs_strategy_worst, minutes_worst) if m_worst <= m_best]
    payoffs_strategy_worst_stratified.append(pay_worst[-1] if len(pay_worst) else 0.0) 

payoffs_strategy_random = np.cumsum([r[i] for r, i in zip(payoffs.T, randomly_played_arms)])
minutes_random = np.cumsum([c[i] for c, i in zip(costs.T, randomly_played_arms)]) * maximum_duration

result_best_minutes_random = Result(minutes_best, payoffs_strategy_best,  f"scipt {idx_best + 1}", result_best_minutes.color)
result_worst_minutes_random = Result(minutes_worst, payoffs_strategy_worst,  f"scipt {idx_worst + 1}", result_worst_minutes.color)
result_random_minutes = Result(minutes_random, payoffs_strategy_random,  result_random_minutes.label, result_random_minutes.color)

# %%
def compute_ci(n, t):
    if t == 0 or n == 0:
        return np.infty
    return np.sqrt(2 * np.log(t) / n) 

def get_best_arm(data: pd.DataFrame):
    best_arm_index = np.argmax(data["ucb payoff"] / np.maximum(data["lcb cost"], 1e-10)) 
    row = data.iloc[best_arm_index]
    return row["arm"]

columns=["arm", 'time', "plays", 'mean payoff', 'mean cost', 'lcb cost', 'ucb payoff', 'reward', 'cost', "ci"]

reward = 0
cost = 0
data_composite = []
timestep_df = []
for i in range(n_samples):
    if i < len(expected_payoffs):
        played_arm = i
    else:
        played_arm = get_best_arm(timestep_df)
    rows_for_timestep = []
    for arm in range(len(expected_payoffs)):
        if i > 0:
            last_row_for_arm = (timestep_df.iloc[arm])
            last_mean_reward = last_row_for_arm["mean payoff"]
            last_mean_cost = last_row_for_arm["mean cost"]
            last_number_plays = last_row_for_arm["plays"]
        else:
            last_mean_reward = 0
            last_mean_cost = 0
            last_number_plays = 0
        if arm == played_arm:
            this_reward = payoffs[arm, i]
            this_cost = costs[arm, i]
            reward += this_reward
            cost += this_cost
            new_plays = last_number_plays + 1
            new_mean_reward = ((last_mean_reward * last_number_plays) + this_reward) / new_plays
            new_mean_cost = ((last_mean_cost * last_number_plays) + this_cost) / new_plays
        else:
            new_mean_reward = last_mean_reward
            new_mean_cost = last_mean_cost
            new_plays = last_number_plays
        new_ci = compute_ci(new_plays, i)
        rows_for_timestep.append([arm, i, new_plays, new_mean_reward, new_mean_cost, new_mean_cost - new_ci, new_mean_reward + new_ci, reward, cost, new_ci])
        data_composite.append([arm, i, new_plays, new_mean_reward, new_mean_cost, new_mean_cost - new_ci, new_mean_reward + new_ci, reward, cost, new_ci])
    timestep_df = pd.DataFrame(rows_for_timestep, columns=columns)

data_composite = pd.DataFrame(data_composite, columns=columns)
data_composite["played"] = data_composite.groupby("arm")["plays"].diff().astype("bool")

payoffs_composite = np.array(data_composite.loc[data_composite["arm"] == 0]["reward"])
played_arms_composite = np.array(data_composite[data_composite["played"]]["arm"])
minutes_composite = np.array(data_composite.loc[data_composite["arm"] == 0]["cost"]) * maximum_duration

result_composite = Result(minutes_composite, payoffs_composite,  "composite", "white")

idx_best = np.argmax(payoff_per_minute)
idx_worst = np.argmin(payoff_per_minute)

payoffs_strategy_best = np.cumsum(payoffs[idx_best])
payoffs_strategy_worst = np.cumsum(payoffs[idx_worst])

minutes_best = costs[idx_best, :].cumsum() * maximum_duration # np.arange(len(payoffs_strategy_best)) * expected_duration_minutes[idx_best]
minutes_worst = costs[idx_worst, :].cumsum() * maximum_duration  # np.arange(len(payoffs_strategy_worst)) * expected_duration_minutes[idx_worst]
minutes_random = np.array([expected_duration_minutes[randomly_played_arms[i]] for i in range(n_samples)]).cumsum()

payoffs_strategy_worst_stratified = []
for m_best in minutes_best:
    pay_worst = [p for p, m_worst in zip(payoffs_strategy_worst, minutes_worst) if m_worst <= m_best]
    payoffs_strategy_worst_stratified.append(pay_worst[-1] if len(pay_worst) else 0.0) 

payoffs_strategy_random = np.cumsum([r[i] for r, i in zip(payoffs.T, randomly_played_arms)])
minutes_random = np.cumsum([c[i] for c, i in zip(costs.T, randomly_played_arms)]) * maximum_duration

result_best_minutes_random = Result(minutes_best, payoffs_strategy_best,  f"scipt {idx_best + 1}", result_best_minutes.color)
result_worst_minutes_random = Result(minutes_worst, payoffs_strategy_worst,  f"scipt {idx_worst + 1}", result_worst_minutes.color)
result_random_minutes = Result(minutes_random, payoffs_strategy_random,  result_random_minutes.label, result_random_minutes.color)

# %%
def compute_ci(n, t):
    if t == 0 or n == 0:
        return np.infty
    max_ratio = 1 / min_cost
    return  max_ratio * np.sqrt(2 * np.log(t) / n)

def get_best_arm(data: pd.DataFrame):
    try:
        best_arm_index = np.argmax(data["mean payoff"] / data["mean cost"] + data["ci"])
    except:
        return rng.choice(range(len(expected_payoffs)))
    row = data.iloc[best_arm_index]
    return row["arm"]

columns = ["arm", 'time', "plays", 
                             'mean payoff', 'mean cost', 
                             'lcb cost', 'ucb payoff', 
                             'reward', 'cost', "ci"]

reward = 0
cost = 0
data_reductive = []
timestep_df = []
for i in range(n_samples):
    if i < len(expected_payoffs):
        played_arm = i
    else:
        played_arm = get_best_arm(timestep_df)
    rows_for_timestep = []
    for arm in range(len(expected_payoffs)):
        if i > 0:
            last_row_for_arm = timestep_df.iloc[arm]
            last_mean_reward = last_row_for_arm["mean payoff"]
            last_mean_cost = last_row_for_arm["mean cost"]
            last_number_plays = last_row_for_arm["plays"]
        else:
            last_mean_reward = 0
            last_mean_cost = 0
            last_number_plays = 0
        
        if arm == played_arm:
            this_reward = payoffs[arm, i]
            this_cost = costs[arm, i]
            reward += this_reward
            cost += this_cost
            new_plays = last_number_plays + 1
            new_mean_reward = ((last_mean_reward * last_number_plays) + this_reward) / new_plays
            new_mean_cost = ((last_mean_cost * last_number_plays) + this_cost) / new_plays
        else:
            new_mean_reward = last_mean_reward
            new_mean_cost = last_mean_cost
            new_plays = last_number_plays
        new_ci = compute_ci(new_plays, i)
        rows_for_timestep.append([arm, i, new_plays, new_mean_reward, new_mean_cost, new_mean_cost - new_ci, new_mean_reward + new_ci, reward, cost, new_ci])
        data_reductive.append([arm, i, new_plays, new_mean_reward, new_mean_cost, new_mean_cost - new_ci, new_mean_reward + new_ci, reward, cost, new_ci])
    timestep_df = pd.DataFrame(rows_for_timestep, columns=columns)

data_reductive = pd.DataFrame(data_reductive, columns=columns)
data_reductive["played"] = data_reductive.groupby("arm")["plays"].diff().astype("bool")

payoffs_reductive = data_reductive.loc[data_reductive["played"]]["reward"]
minutes_reductive = data_reductive.loc[data_reductive["played"]]["cost"] * maximum_duration

result_reductive = Result(minutes_reductive, payoffs_reductive,  "reductive", "salmon")

# %%
def compute_ci(n, t):
    if t == 0 or n == 0:
        return np.infty
    return  np.sqrt(2 * np.log(t) / n)

def get_best_arm(data: pd.DataFrame):
    index = (data["mean payoff"] + data["ci"]) / data["mean cost"]
    index[index.isna()] = np.infty  # 1 / min_cost
    best_arm_index = np.argmax(index)
    row = data.iloc[best_arm_index]
    return row["arm"]

columns=["arm", 'time', "plays", 'mean payoff', "mean cost", 'lcb cost', 'ucb payoff', 'reward', 'cost', "ci"]

reward = 0
cost = 0
data_united = []
timestep_df = []
for i in range(n_samples):
    if i < len(expected_payoffs):
        played_arm = i
    else:
        played_arm = get_best_arm(timestep_df)
    rows_for_timestep = []
    for arm in range(len(expected_payoffs)):
        if i > 0:
            last_row_for_arm = timestep_df.iloc[arm]
            last_mean_reward = last_row_for_arm["mean payoff"]
            last_mean_cost = last_row_for_arm["mean cost"]
            last_number_plays = last_row_for_arm["plays"]
        else:
            last_mean_reward = 0.0
            last_mean_cost = 0.0
            last_number_plays = 0
        if arm == played_arm:
            this_reward = payoffs[arm, i]
            this_cost = costs[arm, i]
            reward += this_reward
            cost += this_cost
            new_plays = last_number_plays + 1
            new_mean_reward = ((last_mean_reward * last_number_plays) + this_reward) / new_plays
            new_mean_cost = ((last_mean_cost * last_number_plays) + this_cost) / new_plays
        else:
            new_mean_reward = last_mean_reward
            new_mean_cost = last_mean_cost
            new_plays = last_number_plays
        new_ci = compute_ci(new_plays, i)
        rows_for_timestep.append([arm, i, new_plays, new_mean_reward, new_mean_cost, new_mean_cost - new_ci, new_mean_reward + new_ci, reward, cost, new_ci])
        data_united.append([arm, i, new_plays, new_mean_reward, new_mean_cost, new_mean_cost - new_ci, new_mean_reward + new_ci, reward, cost, new_ci])
    timestep_df = pd.DataFrame(rows_for_timestep, columns=columns)

data_united = pd.DataFrame(data_united, columns=columns)
data_united["played"] = data_united.groupby("arm")["plays"].diff().astype("bool")

# payoffs_united = np.array(data_united.loc[data_united["arm"] == 0]["reward"])
# played_arms_united = np.array(data_united[data_united["played"]]["arm"])
# minutes_united = np.array(data_united.loc[data_united["arm"] == 0]["cost"]) * maximum_duration

payoffs_united = data_united.loc[data_united["played"]]["reward"]
minutes_united = data_united.loc[data_united["played"]]["cost"] * maximum_duration
result_united = Result(minutes_united, payoffs_united,  "united", "red")

# %%
all_results = [result_worst_minutes, result_best_minutes, result_random_minutes, result_composite, result_reductive, result_united]
plt.fill_between(minutes_best, result_best_minutes.y, result_worst_stratified.y, color="white", alpha=0.3)
for result in all_results:
    ax = sns.lineplot(x=result.x, y=result.y, color=result.color, label=result.label, errorbar=None)

sns.move_legend(ax, "upper left")
sns.despine()
# max_minutes = np.max(minutes_best)
max_payoff = payoffs_strategy_best[len([m for m in minutes_best if m < max_minutes])]
plt.xlim(0, max_minutes)
plt.ylim(0, max_payoff * 1.1)
plt.xlabel("Total duration of calls")
plt.ylabel("Sum of payoffs")
plt.tight_layout(pad=.5)

plt.savefig(os.path.join(os.getcwd(), "figures", "medium_4.png"))

# %%
def compute_asymmetric_ci(mean, n, t, rho=.25):
    if n == 0 or t == 0:
        return 0.0, np.infty
    z = np.sqrt(2 * rho * np.log(t))
    z2 = z ** 2
    ns = mean * n  # number of successes
    nf = n - ns # number of failures
    center = (ns + 0.5 * z2) / (n + z2)  # interval center (not the mean!)
    ci = z / (n + z2) * np.sqrt((ns * nf) / n + z2 / 4)  # interval width
    return center - ci, center + ci

columns=["arm", 'time', "plays", 
                             'mean payoff', 'mean cost', 
                             'lcb cost', 'ucb payoff', 
                             'reward', 'cost', "ci"]

def get_best_arm(data: pd.DataFrame):
    index = data["ucb payoff"] / data["lcb cost"]
    index[index.isna()] = 1 / min_cost
    return np.argmax(index)

reward = 0
cost = 0
timestep_df = None
data_ours = []
for i in range(n_samples):
    if i < len(expected_payoffs):
        played_arm = i
    else:
        played_arm = get_best_arm(timestep_df)
    rows_for_timestep = []
    for arm in range(len(expected_payoffs)):
        if i > 0:
            last_row_for_arm = timestep_df.iloc[arm]
            last_mean_reward = last_row_for_arm["mean payoff"]
            last_mean_cost = last_row_for_arm["mean cost"]
            last_number_plays = last_row_for_arm["plays"]
        else:
            last_mean_reward = 0
            last_mean_cost = 0
            last_number_plays = 0
        if arm == played_arm:
            this_reward = payoffs[arm, i]
            this_cost = costs[arm, i]
            reward += this_reward
            cost += this_cost
            new_plays = last_number_plays + 1
            new_mean_reward = ((last_mean_reward * last_number_plays) + this_reward) / new_plays
            new_mean_cost = ((last_mean_cost * last_number_plays) + this_cost) / new_plays
        else:
            new_mean_reward = last_mean_reward
            new_mean_cost = last_mean_cost
            new_plays = last_number_plays
        lcb_cost, _ = compute_asymmetric_ci(new_mean_cost, new_plays, i)
        _, ucb_payoff = compute_asymmetric_ci(new_mean_reward, new_plays, i)
        rows_for_timestep.append([arm, i, new_plays, new_mean_reward, new_mean_cost, lcb_cost, ucb_payoff, reward, cost, new_mean_cost - lcb_cost])
        data_ours.append([arm, i, new_plays, new_mean_reward, new_mean_cost, lcb_cost, ucb_payoff, reward, cost, new_mean_cost - lcb_cost])
    timestep_df = pd.DataFrame(rows_for_timestep, columns=columns)

data_ours = pd.DataFrame(data_ours, columns=columns)
data_ours["played"] = data_ours.groupby("arm")["plays"].diff().astype("bool")

payoffs_ours = data_ours.loc[data_ours["played"]]["reward"]
minutes_ours = data_ours.loc[data_ours["played"]]["cost"] * maximum_duration

result_ours = Result(minutes_ours, payoffs_ours, "w-UCB", "yellow")

# %%
all_results = [result_worst_minutes, result_best_minutes, result_random_minutes, result_composite, result_reductive, result_united, result_ours]
plt.fill_between(minutes_best, result_best_minutes.y, result_worst_stratified.y, color="white", alpha=0.3)
for result in all_results:
    ax = sns.lineplot(x=result.x, y=result.y, color=result.color, label=result.label, errorbar=None)

sns.move_legend(ax, "center left")
sns.despine()
# max_minutes = np.max(minutes_best)
max_payoff = payoffs_strategy_best[len([m for m in minutes_best if m < max_minutes]) - 1]
plt.xlim(0, max_minutes)
plt.ylim(0, max_payoff * 1.1)
plt.xlabel("Total duration of calls")
plt.ylabel("Sum of payoffs")
plt.tight_layout(pad=.5)

plt.savefig(os.path.join(os.getcwd(), "figures", "medium_5.png"))

# %%
from components.bandits.bandit_util import Aggregate

def compute_eta(mean, variance):
    if mean == 0.0 or mean == 1.0:
        return 1.0
    eta = variance / (mean * (1.0 - mean))
    return min(eta, 1.0)

def compute_asymmetric_ci(mean, n, t, rho=0.25, eta: float = 1.0):
    if n == 0 or t == 0:
        return 0.0, np.infty
    z = np.sqrt(2 * rho * np.log(t))
    z2 = z ** 2 * eta
    z = np.sqrt(z2)
    ns = mean * n  # number of successes
    nf = n - ns # number of failures
    center = (ns + 0.5 * z2) / (n + z2)  # interval center
    ci = z / (n + z2) * np.sqrt((ns * nf) / n + z2 / 4)  # interval width
    return center - ci, center + ci

columns=["arm", 'time', "plays", 
                             'mean payoff', 'mean cost', 
                             'lcb cost', 'ucb payoff', 
                             'reward', 'cost', "ci"]

def get_best_arm(data: pd.DataFrame):
    index = data["ucb payoff"] / data["lcb cost"]
    index[index.isna()] = 1 / min_cost
    return np.argmax(index)

reward = 0
cost = 0
rew_aggregates = [Aggregate() for _ in range(len(expected_payoffs))]
cost_aggregates = [Aggregate() for _ in range(len(expected_payoffs))]

data_omega_star = []
timestep_df = []
for i in range(n_samples):
    if i < len(expected_payoffs):
        played_arm = i
    else:
        played_arm = get_best_arm(timestep_df)
    rows_for_timestep = []
    for arm in range(len(expected_payoffs)):
        if i > 0:
            last_row_for_arm = timestep_df.iloc[arm]
            last_mean_reward = last_row_for_arm["mean payoff"]
            last_mean_cost = last_row_for_arm["mean cost"]
            last_number_plays = last_row_for_arm["plays"]
        else:
            last_mean_reward = 0
            last_mean_cost = 0
            last_number_plays = 0
        if arm == played_arm:
            this_reward = payoffs[arm, i]
            this_cost = costs[arm, i]
            reward += this_reward
            cost += this_cost
            new_plays = last_number_plays + 1
            new_mean_reward = ((last_mean_reward * last_number_plays) + this_reward) / new_plays
            new_mean_cost = ((last_mean_cost * last_number_plays) + this_cost) / new_plays
            rew_aggregates[arm].update(this_reward)
            cost_aggregates[arm].update(this_cost)
        else:
            new_mean_reward = last_mean_reward
            new_mean_cost = last_mean_cost
            new_plays = last_number_plays
        lcb_cost, _ = compute_asymmetric_ci(new_mean_cost, new_plays, i,
                                            eta=compute_eta(cost_aggregates[arm].mean(), cost_aggregates[arm].variance()))
        _, ucb_payoff = compute_asymmetric_ci(new_mean_reward, new_plays, i,
                                              eta=compute_eta(rew_aggregates[arm].mean(), rew_aggregates[arm].variance()))
        rows_for_timestep.append([arm, i, new_plays, new_mean_reward, new_mean_cost, lcb_cost, ucb_payoff, reward, cost, new_mean_cost - lcb_cost])
        data_omega_star.append([arm, i, new_plays, new_mean_reward, new_mean_cost, lcb_cost, ucb_payoff, reward, cost, new_mean_cost - lcb_cost])
    timestep_df = pd.DataFrame(rows_for_timestep, columns=columns)

data_omega_star = pd.DataFrame(data_omega_star, columns=columns)
data_omega_star["played"] = data_omega_star.groupby("arm")["plays"].diff().astype("bool")

payoffs_omega_star = data_omega_star.loc[data_omega_star["played"]]["reward"]
minutes_omega_star = data_omega_star.loc[data_omega_star["played"]]["cost"] * maximum_duration

result_ours_star = Result(minutes_omega_star, payoffs_omega_star, "w*-UCB", "lightgoldenrodyellow")

# %%
all_results = [result_worst_minutes, result_best_minutes, result_random_minutes, result_composite, result_reductive, result_united, result_ours, result_ours_star]
plt.fill_between(minutes_best, result_best_minutes.y, result_worst_stratified.y, color="white", alpha=0.3)
for result in all_results:
    ax = sns.lineplot(x=result.x, y=result.y, color=result.color, label=result.label, errorbar=None)

sns.move_legend(ax, "center left", frameon=True)
sns.despine()
# max_minutes = np.max(minutes_best)
max_payoff = payoffs_strategy_best[len([m for m in minutes_best if m < max_minutes]) - 1]
plt.xlim(0, max_minutes)
plt.ylim(0, max_payoff * 1.1)
plt.xlabel("Total duration of calls")
plt.ylabel("Sum of payoffs")
plt.tight_layout(pad=.5)

plt.savefig(os.path.join(os.getcwd(), "figures", "medium_6.png"))
